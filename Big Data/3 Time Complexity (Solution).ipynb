# %%
# import symbolic capability to Python
from sympy import *
from sympy.abc import *
from sympy.plotting import plot
from IPython.display import display
# print things all pretty
init_printing()

# %% [markdown]
# # Size of the problem: n

# %%
n = symbols("n", positive=True, real=True)

# %% [markdown]
# # Different Functions f with different Time complexity

# %%
f_constant = 20
f_linear = 4 * n + 10
f_linear2 = 10 * n +1
f_quadratic = 1/4 * n**2 + 1/2*n +1 
f_quadratic2 = 1/8 * n**2

# %% [markdown]
# # Definition of Order of Growth (O) ("Big O")
#
# Order of growth (O) is a set of functions whose asymptotic growth behavior is considered equivalent:
#
# Two functions f(n) and g(n) have the equivalent order of growth if $\displaystyle \lim_{n \rightarrow \infty} \frac{f(n)}{g(n)} = c$ with $c > 0$ and $c < \infty $.
#
#
# f(n) has a higher order of growth than g(n) if
# $\displaystyle \lim_{n \rightarrow \infty} \frac{f(n)}{g(n)} = \infty $.
#
# f(n) has a smaller order of growth than g(n) if $\displaystyle \lim_{n \rightarrow \infty} \frac{f(n)}{g(n)} = 0 $.
#
# $f(n) \in O(g(n))$ if $\displaystyle \lim_{n \rightarrow \infty} \frac{f(n)}{g(n)} = c$ with $c < \infty $.

# %% [markdown]
# # Test Order of Growth with the Sympy limit function

# %%
limit(f_quadratic / f_quadratic2, n, oo)
# Out:
# 2.00000000000000

# %%
limit(f_quadratic / f_linear, n, oo)
# Out:
# ∞

# %%
limit( f_linear2 / f_quadratic2, n, oo)
# Out:
# 0

# %% [markdown]
# # Plotting Time Complexity

# %%
expr_range = (n,0,30)
p = plot(
    f_constant,
    f_linear,
    f_quadratic,
    expr_range,
    show = False,
    legend = True
);

p[0].line_color = 'g'
p[1].line_color = 'b'
p[2].line_color = 'r'



p[0].label = 'constant'
p[1].label = 'linear'
p[2].label = 'quadratic'

p.show()

# %% [markdown]
# # Crossover point

# %%
e1 = Eq(f_quadratic, f_linear)
e1
# Out:
#       2
# 0.25⋅n  + 0.5⋅n + 1 = 4⋅n + 10

# %%
solve(e1, n)
# Out:
# [16.2195444572929]

# %%
solve(e1, n)[0].evalf()
# Out:
# 16.2195444572929

# %% [markdown]
# # Todo

# %%
# TODO: Define 
# - a logarithmic function
f_logarithmic = log(2*n)
# - a log-linear (n log n) function
f_loglinear = n*log(2*n) + 2
# - a cubic function
f_cubic = 2*(n**3)+2*n+1
# - an exponential function
f_exponential = 3*exp(n)
# - a factorial function
f_factorial = 2*factorial(0.5*n)

# %%
def get_rand(iterations):
    functionstr = ['f_logarithmic', 'f_loglinear', 'f_cubic', 'f_exponential', 'f_factorial']
    arr = []
    
    def looper():
        for i in range(2):
            r = random.randrange(0,5)
            choosed = functions[r]
            if not choosed in arr and len(arr) < iterations:
                arr.append(choosed)
                
        if len(arr) == iterations:
            pass
        else:
            looper()
            
    looper()
    return arr

# %%
# TODO create multiple plots with different combinations of functions
import matplotlib.pyplot as plt
import random

total = 3
combinations = 3

for i in range(total):
    f = get_rand(combinations)
    
    p = plot(
        eval(f[0]),
        eval(f[1]),
        eval(f[2]),
        show = False,
        legend = True
    );
    
    p[0].line_color = 'g'
    p[1].line_color = 'b'
    p[2].line_color = 'r'
    
    p[0].label = f[0]
    p[1].label = f[1]
    p[2].label = f[2]
    
    p.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sympy\core\evalf.py in evalf(x, prec, options)
#    1307     try:
# -> 1308         rf = evalf_table[x.func]
#    1309         r = rf(x, prec, options)
#
# KeyError: factorial
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sympy\plotting\experimental_lambdify.py in __call__(self, args, kwargs)
#     194             #The result can be sympy.Float. Hence wrap it with complex type.
# --> 195             result = complex(self.lambda_func(args))
#     196             if abs(result.imag) > 1e-7 * abs(result):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sympy\plotting\experimental_lambdify.py in __call__(self, *args, **kwargs)
#     316     def __call__(self, *args, **kwargs):
# --> 317         return self.lambda_func(*args, **kwargs)
#     318
#
# <string> in <lambda>(x0)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sympy\core\function.py in __new__(cls, *args, **options)
#     462                 pr = max(cls._should_evalf(a) for a in result.args)
# --> 463                 result = result.evalf(mlib.libmpf.prec_to_dps(pr))
#     464
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sympy\core\evalf.py in evalf(self, n, subs, maxn, chop, strict, quad, verbose)
#    1441         try:
# -> 1442             result = evalf(self, prec + 4, options)
#    1443         except NotImplementedError:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sympy\core\evalf.py in evalf(x, prec, options)
#    1313             x = x.subs(evalf_subs(prec, options['subs']))
# -> 1314         xe = x._eval_evalf(prec)
#    1315         if xe is None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sympy\core\function.py in _eval_evalf(self, prec)
#     585         with mpmath.workprec(prec):
# --> 586             v = func(*args)
#     587
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\mpmath\ctx_mp_python.py in f(x, **kwargs)
#    1011                 try:
# -> 1012                     return ctx.make_mpf(mpf_f(x._mpf_, prec, rounding))
#    1013                 except ComplexResult:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\mpmath\libmp\gammazeta.py in mpf_factorial(x, prec, rnd)
#    2356 def mpf_factorial(x, prec, rnd='d'):
# -> 2357     return mpf_gamma(x, prec, rnd, 1)
#    2358
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\mpmath\libmp\gammazeta.py in mpf_gamma(x, prec, rnd, type)
#    1953                 return fzero
# -> 1954             raise ValueError("gamma function pole")
#    1955         # n = x
#
# ValueError: gamma function pole
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sympy\core\evalf.py in evalf(x, prec, options)
#    1307     try:
# -> 1308         rf = evalf_table[x.func]
#    1309         r = rf(x, prec, options)
#
# KeyError: factorial
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-edee759ff89a> in <module>
#      25     p[2].label = f[2]
#      26
# ---> 27     p.show()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sympy\plotting\plot.py in show(self)
#     185             self._backend.close()
#     186         self._backend = self.backend(self)
# --> 187         self._backend.show()
#     188
#     189     def save(self, path):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sympy\plotting\plot.py in show(self)
#    1070
#    1071     def show(self):
# -> 1072         self.process_series()
#    1073         #TODO after fixing https://github.com/ipython/ipython/issues/1255
#    1074         # you can uncomment the next line and remove the pyplot.show() call
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sympy\plotting\plot.py in process_series(self)
#     932             # Create the collections
#     933             if s.is_2Dline:
# --> 934                 collection = self.LineCollection(s.get_segments())
#     935                 self.ax.add_collection(collection)
#     936             elif s.is_contour:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sympy\plotting\plot.py in get_segments(self)
#     531                 self.end=np.log10(self.end)
#     532
# --> 533             f_start = f(self.start)
#     534             f_end = f(self.end)
#     535             sample([self.start, f_start], [self.end, f_end], 0)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sympy\plotting\experimental_lambdify.py in __call__(self, args, kwargs)
#     230                                                     use_evalf=True,
#     231                                                     complex_wrap_evalf=True)
# --> 232                 result = self.lambda_func(args)
#     233                 warnings.warn('The evaluation of the expression is'
#     234                         ' problematic. We are trying a failback method'
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sympy\plotting\experimental_lambdify.py in __call__(self, *args, **kwargs)
#     315
#     316     def __call__(self, *args, **kwargs):
# --> 317         return self.lambda_func(*args, **kwargs)
#     318
#     319
#
# <string> in <lambda>(x0)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sympy\core\function.py in __new__(cls, *args, **options)
#     461             if pr2 > 0:
#     462                 pr = max(cls._should_evalf(a) for a in result.args)
# --> 463                 result = result.evalf(mlib.libmpf.prec_to_dps(pr))
#     464
#     465         return result
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sympy\core\evalf.py in evalf(self, n, subs, maxn, chop, strict, quad, verbose)
#    1440             options['quad'] = quad
#    1441         try:
# -> 1442             result = evalf(self, prec + 4, options)
#    1443         except NotImplementedError:
#    1444             # Fall back to the ordinary evalf
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sympy\core\evalf.py in evalf(x, prec, options)
#    1312         if 'subs' in options:
#    1313             x = x.subs(evalf_subs(prec, options['subs']))
# -> 1314         xe = x._eval_evalf(prec)
#    1315         if xe is None:
#    1316             raise NotImplementedError
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sympy\core\function.py in _eval_evalf(self, prec)
#     584
#     585         with mpmath.workprec(prec):
# --> 586             v = func(*args)
#     587
#     588         return Expr._from_mpmath(v, prec)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\mpmath\ctx_mp_python.py in f(x, **kwargs)
#    1010             if hasattr(x, '_mpf_'):
#    1011                 try:
# -> 1012                     return ctx.make_mpf(mpf_f(x._mpf_, prec, rounding))
#    1013                 except ComplexResult:
#    1014                     # Handle propagation to complex
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\mpmath\libmp\gammazeta.py in mpf_factorial(x, prec, rnd)
#    2355
#    2356 def mpf_factorial(x, prec, rnd='d'):
# -> 2357     return mpf_gamma(x, prec, rnd, 1)
#    2358
#    2359 def mpc_factorial(x, prec, rnd='d'):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\mpmath\libmp\gammazeta.py in mpf_gamma(x, prec, rnd, type)
#    1952             if type == 2:
#    1953                 return fzero
# -> 1954             raise ValueError("gamma function pole")
#    1955         # n = x
#    1956         n = man << exp
#
# ValueError: gamma function pole

# %%
# TODO create a log-log plot with your factorial, exponential, quadratic, log-linear, and linear function

expr_range = (n,0,20)
p = plot(
    f_loglinear,
    f_linear,
    f_quadratic,
    f_exponential,
    f_factorial,
    expr_range,
    show = False,
    legend = True,
    yscale='log'
)

p[0].line_color = 'g'
p[1].line_color = 'b'
p[2].line_color = 'r'
p[3].line_color = 'black'
p[3].line_color = 'y'

p[0].label = 'f_loglinear'
p[1].label = 'f_linear'
p[2].label = 'f_quadratic'
p[3].label = 'f_exponential'
p[4].label = 'f_factorial'
p.show()
# Out:
# C:\Users\z003x9pk\AppData\Local\Continuum\anaconda3\lib\site-packages\sympy\plotting\experimental_lambdify.py:233: UserWarning: The evaluation of the expression is problematic. We are trying a failback method that may still work. Please report this as a bug.
#   warnings.warn('The evaluation of the expression is'

# %%
# TODO Calculate one crossover point for two functions
e2 = Eq(f_linear, f_loglinear)
print(e2)

solve(e2, n)

solve(e2, n)[0].evalf()
# Out:
# Eq(4*n + 10, n*log(2*n) + 2)
# 34.4378250848415
